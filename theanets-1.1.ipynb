# %%
import climate
import theanets
import logging
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import time
import numpy as np
from theanets.trainer import SupervisedPretrainer
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
nlayers = 4
module_size=20 #cm
module_cell = 5 #per edge
distance_between_layers = 5 #cm
ncells=module_cell*module_cell*nlayers
nhidden=ncells
nhidden_layers = 10
layers = (ncells,) + tuple([nhidden for i in range(nhidden_layers)])
#net = theanets.Regressor((ncells,ncells,ncells,ncells,ncells,ncells,ncells,ncells,ncells,ncells,ncells,(ncells,'logistic')))
trainer = theanets.Experiment(theanets.feedforward.Regressor(layers=(ncells,ncells,ncells,ncells,(ncells,'logistic'))),'layerwise')
maximum_hight = nlayers * distance_between_layers
theta_max = math.atan(0.5 * module_size / maximum_hight)
theta_min = -1 * theta_max
y = []
y.append(0)
y_prime = []
y_prime.append(0)
z = []
z.append(0)
x = []
x.append(0)
for i in range (nlayers) :
    y.append((i+1) * distance_between_layers)
    y_prime.append((i+1) * distance_between_layers)
    z.append(0)
    x.append(0)
spent = []
list_error = []
color_list = ['bo','yo','ro','co','mo','go','ko','wo']
min_ntracks = 4
max_ntracks = 4
nsamples = 100000
#nsamples = 2 * ncells * ncells * (nhidden_layers + 1)
#print nsamples
training_ratio = 0.8
ds_input = np.zeros((nsamples,ncells))
ds_output = np.zeros((nsamples,ncells))
cut = int(nsamples * training_ratio)

# %%
def addSample (sample_number = 1,sampleInput = np.zeros (ncells),sampleOutput = np.zeros (ncells)) :
    for i in range (ncells) :
        ds_input[sample_number][i] = sampleInput[i]
        ds_output[sample_number][i] = sampleOutput[i]
    
def sample_creater(sample_number = 1,display = False) :                  # creates a sample with a random number of tracks
    sampleInput = np.zeros (ncells)
    sampleOutput = np.zeros (ncells)
    ntracks = int( uniform(min_ntracks, max_ntracks ) ) #should be a better model than flat
    sample_matrix = [[0 for t in range(nlayers + 1)] for t in range(ntracks)]
# first argument of each row is track's radius and the other "nlayers" ones are hit indices of that track
# then we would be able to sort these hits by their radius
    
# theta is the angle between the circle plane and xy plane. we randomly choose two points in the second and 4th layer and then fit a circle through these two points and also the coordinate origin
# as y is fixed for each layer and z can be derived easily by y*tan(theta) , to specify a point in a layer we only need x of it
    track = 0
    while track < ntracks :
        theta = uniform (theta_min,theta_max)
        x[2] = uniform (-1*module_size/2.0,module_size/2.0)
        x[4] = uniform (-1*module_size/2.0,module_size/2.0)
        for i in range (4) :
            y_prime[i+1] = y[i+1] / cos(theta)
            z[i+1] = y[i+1] * tan(theta)
        # center point of our circle
        x_c = 0.5 * (((x[2]**2 + y_prime[2]**2) * y_prime[4]/y_prime[2] ) - x[4]**2 - y_prime[4]**2 )/ (x[2] * y_prime[4]/y_prime[2] - x[4])
        y_c = 0.5 * (x[2]**2 + y_prime[2]**2 - 2 * x[2] * x_c) / y_prime[2]
        R = sqrt(x_c**2 + y_c**2)
# y_prime is the y component when we place our coordinate on the circle plane and as the layers are parallel, it would be y/cos(theta) for each layer
        if x[2] > 0.5 * x[4] :
            x[1] = x_c + sqrt(R**2 - (y_prime[1] - y_c)**2)
            x[3] = x_c + sqrt(R**2 - (y_prime[3] - y_c)**2)
        else :
            x[1] = x_c - sqrt(R**2 - (y_prime[1] - y_c)**2)
            x[3] = x_c - sqrt(R**2 - (y_prime[3] - y_c)**2)
        sample_matrix [track][0] = R
        x_edge = (-1) * module_size / 2.0
        z_edge = (-1) * module_size / 2.0
        
        track_hits = np.zeros(nlayers)
        no_good = False
        for layer in range (1,nlayers+1) :
            # local indices on the module
            index_hit1 = int( (x[layer] - x_edge ) / module_size * module_cell )
            index_hit2 = int( (z[layer] - z_edge ) / module_size * module_cell )
            # transform into the global index
            hit = module_cell**2 * (layer - 1) + index_hit2 * module_cell + index_hit1
            track_hits[layer-1] = hit
            if sampleInput[hit] == 1:
                    #discard this track
                    no_good = True
        if no_good:
            #print "discarding an overlaping track"
            continue
        else:
            for (layer,hit) in enumerate(track_hits):
                sampleInput[int(hit)] = 1
                sample_matrix [track][layer+1] = int(hit)
        if display:
            for i in range (0,5) :
                plt.figure(1)
                plt.plot(x[i],y_prime[i],color_list[track])
                axis([-module_size/2. + 1 , module_size/2. + 1, 0, maximum_hight/cos(theta) + 1])
                plt.suptitle('x - y_prime (perpendicular view of the circle plane)')
                plt.xlabel('x')
                plt.ylabel('y_prime')
                plt.figure(2)
                plt.plot(x[i],z[i],color_list[track])
                axis([-module_size/2. + 1, module_size/2. + 1,-module_size/2. + 1, module_size/2. + 1])
                plt.suptitle('x - z')
                plt.xlabel('x')
                plt.ylabel('z')
                plt.figure(3)
                plt.plot(z[i],y[i],color_list[track])
                axis([-module_size/2. + 1, module_size/2. + 1, 0, maximum_hight/cos(theta) + 1])
                plt.suptitle('z - y')
                plt.xlabel('z')
                plt.ylabel('y')
        track += 1
    sample_matrix.sort(key=lambda x: x[0])
    for i in range (ntracks) :
        for j in range(1,nlayers+1) :
            sampleOutput[sample_matrix[i][j]] = (i+1)/float(ntracks)
    if display == False :
        addSample(sample_number,sampleInput,sampleOutput)
        
def new_samples() :
    ds_input = np.zeros((nsamples,ncells))
    ds_output = np.zeros((nsamples,ncells))
    for i in range (nsamples) :
        sample_creater(i,False)

# %%
sample_creater(i,True)

# %%
new_samples()

# %%
# we try to create some training samples and train on them and then check the mean error in some testing samples
# a function of iteration and train per iterations
e = []
for i in range(10) :
    e.append(0)
train = ds_input[:cut], ds_output[:cut]
valid = ds_input[cut:], ds_output[cut:]
niter=4
ntrain=1
for i in range (7,niter+5) :
    # training on training samples
    for j in range (ntrain) :
        start = time.mktime(time.gmtime())
        print "training started ... "
        e[i-1] = trainer.train(train,valid, algo='rprop',learning_rate=10**(-1*i),batch_size=100)
        print "\ttraining ended"
        stop = time.mktime (time.gmtime())
        spent.append (stop - start)
        print "training time (seconds) \t" , stop - start
# Out:
# training started ...
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-16-315a6e6dec63> in <module>()
#      13         start = time.mktime(time.gmtime())
#      14         print "training started ... "
# ---> 15         e[i-1] = trainer.train(train,valid, algo='rprop',learning_rate=10**(-1*i),batch_size=100)
#      16         print "\ttraining ended"
#      17         stop = time.mktime (time.gmtime())
#
# /tmp/theanets/theanets/main.pyc in train(self, *args, **kwargs)
#      55             dataset, at the conclusion of training.
#      56         '''
# ---> 57         return self.network.train(*args, **kwargs)
#      58
#      59     def itertrain(self, *args, **kwargs):
#
# /tmp/theanets/theanets/graph.pyc in train(self, *args, **kwargs)
#     349         '''
#     350         monitors = None
# --> 351         for monitors in self.itertrain(*args, **kwargs):
#     352             pass
#     353         return monitors
#
# /tmp/theanets/theanets/graph.pyc in itertrain(self, train, valid, algo, subalgo, save_every, save_progress, **kwargs)
#     324         # train it!
#     325         start = datetime.datetime.utcnow()
# --> 326         for i, monitors in enumerate(algo.itertrain(train, valid, **kwargs)):
#     327             yield monitors
#     328             now = datetime.datetime.utcnow()
#
# /tmp/theanets/theanets/trainer.pyc in itertrain(self, train, valid, **kwargs)
#      64                 params=self.network.params,
#      65                 monitor_gradients=kwargs.get('monitor_gradients', False),
# ---> 66         ).iterate(train, valid=valid, **kwargs):
#      67             yield monitors
#      68
#
# /usr/local/lib/python2.7/site-packages/downhill-0.2.0-py2.7.egg/downhill/base.pyc in iterate(self, train, valid, patience, validate_every, min_improvement, max_gradient_norm, max_gradient_elem, learning_rate, momentum, nesterov, **kwargs)
#     386
#     387         self._prepare(**kwargs)
# --> 388         self._compile()
#     389
#     390         if valid is None:
#
# /usr/local/lib/python2.7/site-packages/downhill-0.2.0-py2.7.egg/downhill/base.pyc in _compile(self)
#     117         label = self.__class__.__name__
#     118         logging.info('compiling %s function', label)
# --> 119         updates = list(self._updates) + list(self._get_updates())
#     120         self.f_step = theano.function(self._inputs,
#     121                                       self._monitor_exprs,
#
# /usr/local/lib/python2.7/site-packages/downhill-0.2.0-py2.7.egg/downhill/base.pyc in _get_updates(self)
#     132         '''
#     133         for param, grad in self._differentiate():
# --> 134             for var, expr in self._get_updates_for(param, grad):
#     135                 if self.momentum == 0 or var != param:
#     136                     yield var, expr
#
# /usr/local/lib/python2.7/site-packages/downhill-0.2.0-py2.7.egg/downhill/adaptive.pyc in _get_updates_for(self, param, grad)
#      95     def _get_updates_for(self, param, grad):
#      96         grad_tm1 = shared_like(param, 'grad')
# ---> 97         step_tm1 = shared_like(param, 'step', self.learning_rate.eval())
#      98         test = grad * grad_tm1
#      99         diff = TT.lt(test, 0)
#
# /usr/local/lib/python2.7/site-packages/theano/gof/graph.pyc in eval(self, inputs_to_values)
#     410         inputs = tuple(sorted(inputs_to_values.keys(), key=id))
#     411         if not inputs in self._fn_cache:
# --> 412             self._fn_cache[inputs] = theano.function(inputs, self)
#     413         args = [inputs_to_values[param] for param in inputs]
#     414
#
# /usr/local/lib/python2.7/site-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     264                 allow_input_downcast=allow_input_downcast,
#     265                 on_unused_input=on_unused_input,
# --> 266                 profile=profile)
#     267     # We need to add the flag check_aliased inputs if we have any mutable or
#     268     # borrowed used defined inputs
#
# /usr/local/lib/python2.7/site-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     509     return orig_function(inputs, cloned_outputs, mode,
#     510             accept_inplace=accept_inplace, name=name, profile=profile,
# --> 511             on_unused_input=on_unused_input)
#     512
#     513
#
# /usr/local/lib/python2.7/site-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input)
#    1464                    profile=profile,
#    1465                    on_unused_input=on_unused_input).create(
# -> 1466                        defaults)
#    1467
#    1468     t2 = time.time()
#
# /usr/local/lib/python2.7/site-packages/theano/compile/function_module.pyc in create(self, input_storage, trustme)
#    1322             theano.config.traceback.limit = 0
#    1323             _fn, _i, _o = self.linker.make_thunk(
# -> 1324                 input_storage=input_storage_lists)
#    1325         finally:
#    1326             theano.config.traceback.limit = limit_orig
#
# /usr/local/lib/python2.7/site-packages/theano/gof/link.pyc in make_thunk(self, input_storage, output_storage)
#     517     def make_thunk(self, input_storage=None, output_storage=None):
#     518         return self.make_all(input_storage=input_storage,
# --> 519                              output_storage=output_storage)[:3]
#     520
#     521     def make_all(self, input_storage, output_storage):
#
# /usr/local/lib/python2.7/site-packages/theano/gof/vm.pyc in make_all(self, profiler, input_storage, output_storage)
#     895                                                  storage_map,
#     896                                                  compute_map,
# --> 897                                                  no_recycling))
#     898                 if not hasattr(thunks[-1], 'lazy'):
#     899                     # We don't want all ops maker to think about lazy Ops.
#
# /usr/local/lib/python2.7/site-packages/theano/gof/op.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     737                 logger.debug('Trying CLinker.make_thunk')
#     738                 outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 739                                         output_storage=node_output_storage)
#     740                 fill_storage, node_input_filters, node_output_filters = outputs
#     741
#
# /usr/local/lib/python2.7/site-packages/theano/gof/cc.pyc in make_thunk(self, input_storage, output_storage, keep_lock)
#    1071         cthunk, in_storage, out_storage, error_storage = self.__compile__(
#    1072             input_storage, output_storage,
# -> 1073             keep_lock=keep_lock)
#    1074
#    1075         res = _CThunk(cthunk, init_tasks, tasks, error_storage)
#
# /usr/local/lib/python2.7/site-packages/theano/gof/cc.pyc in __compile__(self, input_storage, output_storage, keep_lock)
#    1013                                     input_storage,
#    1014                                     output_storage,
# -> 1015                                     keep_lock=keep_lock)
#    1016         return (thunk,
#    1017                 [link.Container(input, storage) for input, storage in
#
# /usr/local/lib/python2.7/site-packages/theano/gof/cc.pyc in cthunk_factory(self, error_storage, in_storage, out_storage, keep_lock)
#    1440         else:
#    1441             module = get_module_cache().module_from_key(
# -> 1442                 key=key, lnk=self, keep_lock=keep_lock)
#    1443
#    1444         vars = self.inputs + self.outputs + self.orphans
#
# /usr/local/lib/python2.7/site-packages/theano/gof/cmodule.pyc in module_from_key(self, key, lnk, keep_lock)
#    1052         # Is the source code already in the cache?
#    1053         module_hash = get_module_hash(src_code, key)
# -> 1054         module = self._get_from_hash(module_hash, key, keep_lock=keep_lock)
#    1055         if module is not None:
#    1056             return module
#
# /usr/local/lib/python2.7/site-packages/theano/gof/cmodule.pyc in _get_from_hash(self, module_hash, key, keep_lock)
#     955             with compilelock.lock_ctx(keep_lock=keep_lock):
#     956                 try:
# --> 957                     key_data.add_key(key, save_pkl=bool(key[0]))
#     958                     key_broken = False
#     959                 except cPickle.PicklingError:
#
# /usr/local/lib/python2.7/site-packages/theano/gof/cmodule.pyc in add_key(self, key, save_pkl)
#     465         self.keys.add(key)
#     466         if save_pkl:
# --> 467             self.save_pkl()
#     468
#     469     def remove_key(self, key, save_pkl=True):
#
# /usr/local/lib/python2.7/site-packages/theano/gof/cmodule.pyc in save_pkl(self)
#     483         try:
#     484             with open(self.key_pkl, 'wb') as f:
# --> 485                 cPickle.dump(self, f, protocol=cPickle.HIGHEST_PROTOCOL)
#     486         except cPickle.PicklingError:
#     487             _logger.warning("Cache leak due to unpickle-able key data %s",
#
# IOError: [Errno 28] No space left on device

# %%
e
# Out:
# [0,
#  0,
#  0,
#  0,
#  (OrderedDict([('loss', 0.046494191713814248), ('err', 0.046494191713814248)]),
#   OrderedDict([('loss', 0.038471469152615879), ('err', 0.038471469152615879)])),
#  (OrderedDict([('loss', 0.041824774119626387), ('err', 0.041824774119626387)]),
#   OrderedDict([('loss', 0.037026568585543769), ('err', 0.037026568585543769)])),
#  0,
#  0,
#  0,
#  0]

# %%
plt.plot(trainer.network.predict(valid[0])[4])
plt.xlabel('hit index')

# %%
plt.plot(ds_output[8004])
plt.xlabel('hit index')

# %%
plt.hist([val for val in trainer.network.predict(valid[0])[4] if val > 0.1 ], bins = 20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-5d7a243017cf> in <module>()
# ----> 1 plt.hist([val for val in trainer.network.predict(valid[0])[4] if val > 0.1 ], bins = 20)
#
# /usr/local/lib/python2.7/site-packages/matplotlib-1.4.2-py2.7-linux-x86_64.egg/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2894                       histtype=histtype, align=align, orientation=orientation,
#    2895                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2896                       stacked=stacked, **kwargs)
#    2897         draw_if_interactive()
#    2898     finally:
#
# /usr/local/lib/python2.7/site-packages/matplotlib-1.4.2-py2.7-linux-x86_64.egg/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5572         elif len(flat) == 1 and not binsgiven:
#    5573             raise ValueError(
# -> 5574                 "x has only one data point. bins or range kwarg must be given")
#    5575
#    5576         # Massage 'x' for processing.
#
# ValueError: x has only one data point. bins or range kwarg must be given
# INFO (theano.gof.compilelock): Refreshing lock /root/.theano/compiledir_Linux-2.6-el6.x86_64-x86_64-with-redhat-6.6-Carbon-x86_64-2.7.8-64/lock_dir/lock
# INFO:theano.gof.compilelock:Refreshing lock /root/.theano/compiledir_Linux-2.6-el6.x86_64-x86_64-with-redhat-6.6-Carbon-x86_64-2.7.8-64/lock_dir/lock
# WARNING (theano.gof.compilelock): Refreshing lock failed, we release the lock before raising again the exception
# WARNING:theano.gof.compilelock:Refreshing lock failed, we release the lock before raising again the exception
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/atexit.py", line 24, in _run_exitfuncs
#     func(*targs, **kargs)
#   File "/usr/local/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1344, in _on_atexit
#     with compilelock.lock_ctx():
#   File "/usr/local/lib/python2.7/contextlib.py", line 17, in __enter__
#     return self.gen.next()
#   File "/usr/local/lib/python2.7/site-packages/theano/gof/compilelock.py", line 54, in lock_ctx
#     get_lock(lock_dir=lock_dir, **kw)
#   File "/usr/local/lib/python2.7/site-packages/theano/gof/compilelock.py", line 111, in get_lock
#     refresh_lock(lockpath)
#   File "/usr/local/lib/python2.7/site-packages/theano/gof/compilelock.py", line 322, in refresh_lock
#     lock_write = open(lock_file, 'w')
# IOError: [Errno 2] No such file or directory: '/root/.theano/compiledir_Linux-2.6-el6.x86_64-x86_64-with-redhat-6.6-Carbon-x86_64-2.7.8-64/lock_dir/lock'
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/atexit.py", line 24, in _run_exitfuncs
#     func(*targs, **kargs)
#   File "/usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 3189, in atexit_operations
#     self.history_manager.end_session()
#   File "/usr/local/lib/python2.7/site-packages/IPython/core/history.py", line 521, in end_session
#     self.writeout_cache()
#   File "<string>", line 2, in writeout_cache
#   File "/usr/local/lib/python2.7/site-packages/IPython/core/history.py", line 68, in needs_sqlite
#     return f(self, *a, **kw)
#   File "/usr/local/lib/python2.7/site-packages/IPython/core/history.py", line 727, in writeout_cache
#     self._writeout_input_cache(conn)
#   File "/usr/local/lib/python2.7/site-packages/IPython/core/history.py", line 711, in _writeout_input_cache
#     (self.session_number,)+line)
# OperationalError: disk I/O error
